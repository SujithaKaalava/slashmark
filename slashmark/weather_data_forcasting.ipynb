# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("C:\\Users\\sujit\\Downloads\\weather.csv")
#1.Display information about the dataset
data

#pairplot
# Out:
# C:\Users\sujit\AppData\Local\Temp\ipykernel_8296\5230919.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# ...

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
data['MaxTemp'].unique()
# Out:
# array([24.3, 26.9, 23.4, 15.5, 16.1, 16.9, 18.2, 17. , 19.5, 22.8, 25.2,
#        27.3, 27.9, 30.9, 31.2, 32.1, 30. , 32.3, 33.4, 19.4, 18.5, 28.4,
#        22.2, 28. , 24.1, 20.4, 26.3, 24.2, 26.5, 21.8, 26.8, 25.8, 28.2,
#        29.4, 24.8, 21.5, 20.3, 27.1, 29.9, 21.1, 21.7, 20.9, 21. , 23.1,
#        29.5, 22. , 24.4, 26.7, 28.3, 31.6, 35. , 33.5, 34.2, 25.3, 27.5,
#        34.1, 33.9, 30.3, 35.8, 35.7, 33.8, 33.2, 25.1, 19.6, 24.7, 19.9,
#        22.5, 27.8, 25.7, 28.8, 31.3, 34.9, 23.8, 29.6, 22.6, 27.4, 26. ,
#        26.1, 28.9, 28.6, 25.9, 27.6, 17.3, 18.4, 31.8, 29.2, 31.7, 34.7,
#        33.1, 35.2, 30.2, 26.2, 29.3, 14.8, 24.9, 22.4, 17.4, 20.2, 18.3,
#        18.9, 18.8, 23.3, 14.3, 21.4, 20.5, 22.9, 19.8, 18. , 20.7, 19.3,
#        19.7, 18.7, 20.6, 19. , 21.2, 11.3, 13.8, 17.1, 16.7, 16.8, 17.6,
#        18.1, 19.2, 18.6, 17.9, 16. , 12.3, 14.1, 14.7, 14.5, 17.5, 14. ,
#        15.7, 14.4, 15.1, 16.3, 13.7, 15. , 16.4, 13. , 11.8, 15.9, 11.7,
# ...

# %% [markdown]
# #data visualization using pairplots

# %%
#data visualization using pairplots
sns.pairplot(data[['MinTemp','MaxTemp','Evaporation','Rainfall']])
plt.show()

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df1=data[['MinTemp','Rainfall','Sunshine','Evaporation']]
df1
# Out:
#      MinTemp  Rainfall  Sunshine  Evaporation
# 0        8.0       0.0       6.3          3.4
# 1       14.0       3.6       9.7          4.4
# 2       13.7       3.6       3.3          5.8
# 3       13.3      39.8       9.1          7.2
# 4        7.6       2.8      10.6          5.6
# ..       ...       ...       ...          ...
# 361      9.0       0.0      12.1          7.6
# 362      7.1       0.0      12.7         11.6
# 363     12.5       0.0       5.3          8.4
# 364     12.5       0.0       7.1          5.0
# 365     12.3       0.0      12.6          6.0
#
# [366 rows x 4 columns]

# %%
sns.pairplot(df1)
plt.show()

# %%
#feature engineering

# %%
#data analysis
#descriptive statistics
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
#2.correlation
data[['MinTemp','Rainfall','Sunshine','Evaporation','WindGustSpeed','WindSpeed9am','WindSpeed3pm','RISK_MM']].corr()
# Out:
#                 MinTemp  Rainfall  Sunshine  Evaporation  WindGustSpeed  \
# MinTemp        1.000000  0.201939  0.035711     0.649930       0.218020
# Rainfall       0.201939  1.000000 -0.150990    -0.007293       0.096190
# Sunshine       0.035711 -0.150990  1.000000     0.318025       0.095843
# Evaporation    0.649930 -0.007293  0.318025     1.000000       0.288477
# WindGustSpeed  0.218020  0.096190  0.095843     0.288477       1.000000
# WindSpeed9am   0.127542  0.219637 -0.064522     0.068929       0.527653
# WindSpeed3pm  -0.065922  0.056008  0.072573     0.048601       0.693945
# RISK_MM        0.218551  0.089860 -0.378823     0.076762       0.251991
#
#                WindSpeed9am  WindSpeed3pm   RISK_MM
# MinTemp            0.127542     -0.065922  0.218551
# Rainfall           0.219637      0.056008  0.089860
# Sunshine          -0.064522      0.072573 -0.378823
# Evaporation        0.068929      0.048601  0.076762
# WindGustSpeed      0.527653      0.693945  0.251991
# ...

# %%
#raifall analysis
total_rainy_days=data['RainToday'].value_counts()
average_rainfall=data['Rainfall'].mean()
total_rainfall=data['Rainfall'].sum()

# %%
total_rainy_days
# Out:
# RainToday
# No     300
# Yes     66
# Name: count, dtype: int64

# %%
#wind analysis
common_WindGustDir=data['WindGustDir'].mode()
common_WindGustDir
average_wind=data[['WindGustSpeed','WindSpeed9am','WindSpeed3pm']].mean()
average_wind
# Out:
# WindGustSpeed    39.840659
# WindSpeed9am      9.651811
# WindSpeed3pm     17.986339
# dtype: float64

# %%
#rain risk analysis
data[['Rainfall','RISK_MM']].corr()
# Out:
#           Rainfall  RISK_MM
# Rainfall   1.00000  0.08986
# RISK_MM    0.08986  1.00000

# %% [markdown]
# # Data Visualization (Part 2): Create additional visualizations for insights.

# %%
#wind direction pie chart
plt.title("Distribution of Wind Directions")
plt.pie(data['WindGustDir'].value_counts(),labels=data['WindGustDir'].value_counts().index,autopct="%1.1f%%")
plt.show()

# %%
sns.scatterplot(data[['Rainfall','MinTemp','MaxTemp']])
plt.title("rainfall vs temparature")
plt.show()

# %%
#pressure vs temparature trend
#(data['Pressure9am'],data['Temp9am']).plot
#plt.plot(data['Pressure9am'],data['Temp9am'])
p1=data[['Pressure9am','Temp9am']]
p1.plot(x="Pressure9am",y="Temp9am")
plt.show()

# %%
plt.bar(data['Cloud9am'].value_counts().index,data['Cloud9am'].value_counts())
plt.title("cloud cover comparison")
plt.xlabel("cloud cover")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ## Step 7: Advanced Analysis (e.g., predict Rainfall)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
x=data[['MinTemp','MaxTemp']]
y=data['Rainfall']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)
mean_sqr_error=mean_squared_error(y_test,y_predict)
print("mean error is:{}".format(mean_sqr_error))
# Out:
# mean error is:37.0768456005826

# %%
# Step 8: Conclusions and Insights (analyze each term)
highest_rainfall=max(data['Rainfall'])
print("highest_rainfall:",highest_rainfall)
highest_WindGustSpeed=max(data['WindGustSpeed'])
print("highest_WindGustSpeed:",highest_WindGustSpeed)
RISK_MM=data['RISK_MM']
print("RISK_MM:",max(RISK_MM))
# Out:
# highest_rainfall: 39.8
# highest_WindGustSpeed: 98.0
# RISK_MM: 39.8
